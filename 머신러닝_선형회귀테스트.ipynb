# %% [markdown]
# <a href="https://colab.research.google.com/github/youjuny/Data-test/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%ED%85%8C%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # 판다스 라이브러리 임포트
file_url = 'https://media.githubusercontent.com/media/musthave-ML10/data_source/main/insurance.csv'
data = pd.read_csv(file_url) # 데이터셋 읽기

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges
# count   1338.000000
# mean   13270.422265
# std    12110.011237
# min     1121.873900
# 25%     4740.287150
# 50%     9382.033000
# 75%    16639.912515
# max    63770.428010

# %%
#문제1. # 특성(문제 데이터, 독립변수)와 타겟(정답, 종속변수) 데이터로 나누기
X = data[['age','sex','bmi','children','smoker']]
y = data['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker
# 0      19    0  27.900         0       1
# 1      18    1  33.770         1       0
# 2      28    1  33.000         3       0
# 3      33    1  22.705         0       0
# 4      32    1  28.880         0       0
# ...   ...  ...     ...       ...     ...
# 1333   50    1  30.970         3       0
# 1334   18    0  31.920         0       0
# 1335   18    0  36.850         0       0
# 1336   21    0  25.800         0       0
# 1337   61    0  29.070         0       1
#
# [1338 rows x 5 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state=100)

# %%
#문제3.
#학습용 데이터를 이용해 선형회귀 모델 학습시키기
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#문제4.
#테스트 데이터(X_test)를 예측한 결과 출력

# %%
pred = model.predict(X_test)

# %%
X_test

# %%
pred
